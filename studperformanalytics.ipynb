# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
pd.options.mode.chained_assignment = None

# %%
sp=pd.read_csv('StudentsPerformance.csv')

# %%
sp.head(5)
sp.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#Checking for the missing values
print("Missing values inside each column:")
print(sp.isnull().sum())
# Out:
# Missing values inside each column:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
#checking for the duplicate rows
print("\nNumber of duplicate rows:")
print(sp.duplicated().sum())
# Out:
# Number of duplicate rows:
# 0

# %%
#generating bar plots to show frequency counts for eachcategorical column
sp['gender'].value_counts().plot.bar(title='Frequency Distribution of Gender', color=['red','blue'],figsize=(3,3))
# Out:
# <Axes: title={'center': 'Frequency Distribution of Gender'}, xlabel='gender'>

# %%
sp['race/ethnicity'].value_counts().plot.bar(title='Frequency Distribution of Race/Ethnicity', color=['black','red','green','blue','cyan'],figsize=(3,3))
# Out:
# <Axes: title={'center': 'Frequency Distribution of Race/Ethnicity'}, xlabel='race/ethnicity'>

# %%
sp['parental level of education'].value_counts().plot.bar(title='Frequency distribution of Parental Level of Education',color=['black','red','green','blue','cyan','orange'],figsize=(4,4))
# Out:
# <Axes: title={'center': 'Frequency distribution of Parental Level of Education'}, xlabel='parental level of education'>

# %%
sp['lunch'].value_counts().plot.bar(title='Frequency Distribution of Lunch',color=['red','blue'],figsize=(3,3))
# Out:
# <Axes: title={'center': 'Frequency Distribution of Lunch'}, xlabel='lunch'>

# %%
sp['test preparation course'].value_counts().plot.bar(title='Frequency Distribution of Test Preparation Course',color =['red','blue'],figsize=(3,3))
# Out:
# <Axes: title={'center': 'Frequency Distribution of Test Preparation Course'}, xlabel='test preparation course'>

# %%
#setting default figure size for all plots
plt.rcParams['figure.figsize']=(30,12)

#pie chart for gender distribution
plt.subplot(1,5,1)
size = sp['gender'].value_counts()
labels = 'Female', 'Male'
color = ['red','green']
plt.pie(size, colors = color, labels=labels, autopct = '%1.2f%%')
plt.title('Gender',fontsize = 20)
plt.axis('off')

#pie chart for race/ethnicity distribution
plt.subplot(1,5,2)
size = sp['race/ethnicity'].value_counts()
labels = 'Group C', 'Group D', 'GroupB', 'Group E', 'Group A'
color = ['red', 'green', 'blue', 'cyan', 'orange']
plt.pie(size, colors = color, labels=labels, autopct='%1.2f%%')
plt.title('Race/Ethnicity', fontsize = 20)
plt.axis('off')

#pie chart for lunch type distribution
plt.subplot(1,5,3)
size = sp['lunch'].value_counts()
labels = 'Standard','Free'
color = ['red', 'green']
plt.pie(size, colors = color, labels = labels, autopct = '%1.2f%%')
plt.title ('lunch',fontsize = 20)
plt.axis('off')

#pie chart for Test Prep Coursre Completeion
plt.subplot(1,5,4)
size =  sp['test preparation course'].value_counts()
labels = 'None','Completed'
color = ['red', 'green']
plt.pie(size,colors = color, labels = labels, autopct = '%1.2f%%')
plt.title('Test Course',fontsize = 20)
plt.axis('off')

#pie chart for parental level of education
plt.subplot(1,5,5)
size = sp['parental level of education'].value_counts()
labels = 'some college',"Associate's Degree",'High School','Some high school',"Bachelor's Degree","Master's Degree"
color = ['red','green','blue','cyan','orange','grey']
plt.pie(size, colors=color, labels=labels, autopct='%1.2f%%')
plt.title('Parental Education',fontsize = 20)
plt.axis('off')

#adjust layout to prevent over lap
plt.tight_layout()

#render all of the subplots
plt.show()

# %% [markdown]
# **Number of Male and Female students is almost equal**
# **No of Students is greatest in group C**
# **No of students who have standard lunch are greater**
# **No of students who have not enrolled in any test preparation course is greater**
# **No of students whose parental education is "some college" is greater followed closely by "Associate's degree**

# %%
#Histograms for score distributions
plt.figure(figsize=(20,10))
sns.histplot(sp['math score'],kde = True)
plt.title('Math score distribution',fontsize = 20)
plt.show()

# %% [markdown]
# **Maximum no of students had a maths score of 65**

# %%
sp['reading score'].value_counts().sort_index().plot(kind ='bar')
plt.title('Reading Score Comparison')
plt.show()

# %% [markdown]
# **Maximum no of students had a reading score of 72**

# %%
plt.rcParams['figure.figsize']=(20,10)
sp['writing score'].value_counts().sort_index().plot(kind='bar')
plt.title('writing score comparison',fontsize = 20)
plt.show()

# %% [markdown]
# **Maximum no if students had a writing score of 75**

# %%
#violin plots for scores
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
plt.title('Math Scores')
sns.violinplot(y='math score', data=sp, color = 'blue', linewidth= 2)
plt.subplot(132)
plt.title('Reading Scores')
sns.violinplot(y='reading score',data=sp, color='green', linewidth =2)
plt.subplot(133)
plt.title('Writing Scores')
sns.violinplot(y='writing score',data=sp, color='red',linewidth =2)
plt.show()

# %% [markdown]
# **Max no of students have scored between 60-80 marks in all three subjects**

# %%
#Barplots: scores vs gender
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.title('Math Scores')
sns.barplot(x="gender",y="math score",data=sp)
plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(x="gender",y="reading score",data=sp)
plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(x="gender",y="writing score",data=sp)
plt.show()

# %% [markdown]
# **Male students scored higher in Maths whereas Female students scored higher in Reading and Writing**

# %%
#Barplots: Scores vs Test Prep Course
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.title('Math Scores')
sns.barplot(hue="gender",y="math score",x="test preparation course",data=sp)

plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(hue="gender",y="reading score",x="test preparation course",data=sp)

plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(hue="gender",y="writing score",x="test preparation course",data=sp)
plt.show()

# %% [markdown]
# **Student who completed the test preparation course achieved higher scored in all 3 subjects**

# %%
#barplot: score vs lunch
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.title('Math Scores')
sns.barplot(hue="gender",y="math score",x="lunch",data=sp)

plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(hue="gender",y="reading score",x="lunch",data=sp)

plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(hue="gender",y="writing score",x="lunch",data=sp)
plt.show()

# %% [markdown]
# **Students who choose standard lunch achieved higher scores in all 3 subjects**
